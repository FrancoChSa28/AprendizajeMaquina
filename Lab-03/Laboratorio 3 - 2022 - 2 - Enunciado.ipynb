# %% [markdown]
# # Laboratorio 3 - Tarea - Logistic Regression
#
# El objetivo de esta tarea es pre-procesar un conjunto de datos que será usado en el laboratorio 3.

# %% [markdown]
# ## Objetivos:
#
# * Realizar un análisis exploratorio de datos básico.
# * Pre-procesar un conjunto de datos justificando las decisiones tomadas.

# %%
import numpy as np
import pandas as pd
# Escriba su código aquí
## Puede agregar todas las celdas que desee

# %%
data = pd.read_csv("file.csv", sep=",")

# %%
data.head()

# %% [markdown]
# ### Revisión del tipo de dato junto al % de registros únicos y vacíos de las columnas <font color='blue'>(0.5 ptos)</font>
#
# Revise el tipo de dato de las columnas junto al % de registros únicos y vacíos de las columnas que existen en el dataset.

# %%
# Escriba su código aquí
## Puede agregar todas las celdas que desee

# %% [markdown]
# ### Eliminación de las columnas que no aportan información y de los registros duplicados <font color='blue'>(2.5 ptos)</font>
#
# - Elimine las columnas que no aportan información.
#
#   - **Indique las columnas junto a la razón por la que no aportan información o no se considerará el puntaje**.
#
# - Elimine los registros duplicados.
#
#   - **Indique si usa todas o sólo algunas de las columnas para eliminar los registros duplicados junto a la razón de su elección o no se considerará el puntaje**.
#
# - **Las razones de sus elecciones deben estar justificadas mediante algún cálculo o gráfico para considerar los puntajes**.
#
# - **Se puede usar el mismo cálculo o gráfico en ambas partes**.
#
# - **Se recomienda analizar la correlación entre las columnas**.

# %%
# Escriba su código aquí
## Puede agregar todas las celdas que desee

# %% [markdown]
# ### Truncación de los valores outliers de las columnas <font color='blue'>(5.0 ptos)</font>
#
# En cada una de las columnas que existen en el dataset trunque los valores outliers. Para ello, en cada columna debe hacer uso de la técnica "diagrama de caja" para obtener el límite inferior y superior; a partir de los cuales debe truncar los valores outliers a aquellos límites.
#
# **Para cada columna debe imprimir el límite inferior, límite superior, el número y porcentaje de valores outliers o no se considerará el puntaje**.
#
# La impresión en cada columna debe ser similar a:
#
# ```
# Columna Ingrediente_1:
# Se considera atípicos a los valores mayores al límite superior: 26.35
# Se considera atípicos a los valores mayores al límite inferior: 12.32
# Ello incluye un total de 800 registros (18.65%)
# ```

# %%
# Escriba su código aquí
## Puede agregar todas las celdas que desee
for column_name in data.columns:
  ...

  print(f'Columna {column_name}:')
  print(f'Se considera atípicos a los valores mayores al límite superior: {}')
  print(f'Se considera atípicos a los valores menores al límite inferior: {}')
  print(f'Ello incluye un total de {} registros ({():.2%})\n')

# %% [markdown]
# ### Obtención de la variable dependiente y de las variables independientes <font color='blue'>(1.0 ptos)</font>
#
# La variable dependiente es "Indice Satisfaccion", mientras que el resto son las variables independientes.

# %%
# Escriba su código aquí
## Puede agregar todas las celdas que desee

#Separamos las variables independientes (x) y dependientes (y)
x = data.drop(...)

y = data[...]

# %%
x.shape, y.shape

# %% [markdown]
# ### División estratificada de los datos <font color='blue'>(2.0 ptos)</font>
#
# Realice un "split" **estratificado** con los siguientes parámetros:
#
# - test_size: 0.18
# - random_state: 100

# %%
# Escriba su código aquí
## Puede agregar todas las celdas que desee

#Dividimos el conjunto de datos
x_train, x_test, y_train, y_test = train_test_split(...)

# %% [markdown]
# ### Entrenamiento de una regresión logística <font color='blue'>(2.0 ptos)</font>
#
# Instancie y entrene un modelo de regresión logística

# %%
# Escriba su código aquí
## Puede agregar todas las celdas que desee
model = LogisticRegression(...)

# %%
# Escriba su código aquí
## Puede agregar todas las celdas que desee
model.fit(...)

# %% [markdown]
# ### Visualización de la matriz de confusión <font color='blue'>(3.0 ptos)</font>
#
# Genere 2 matrices de confusión, una para el conjunto de entrenamiento y otra para el conjunto de prueba.
#
# Por cada matriz de confusión debe indicar lo siguiente:
# - True Positives
# - False Positives
# - True Negatives
# - False Negatives
#
# **Debe graficar las matrices de confusión**
#
# Recuerde que para este conjunto de datos las **etiquetas son 0 y 1**, por lo que los valores 0 y 1 hacen referencia a los negativos y positivos, respectivamente.

# %%
# Escriba su código aquí
## Puede agregar todas las celdas que desee

print("Conjunto de entrenamiento")
print(f"Los True Positives son: {tp}")
print(f"Los False Positives son: {fp}")
print(f"Los True Negatives son: {tn}")
print(f"Los False Negatives son: {fn}")

# %%
# Escriba su código aquí
## Puede agregar todas las celdas que desee

print("Conjunto de prueba")
print(f"Los True Positives son: {tp}")
print(f"Los False Positives son: {fp}")
print(f"Los True Negatives son: {tn}")
print(f"Los False Negatives son: {fn}")

# %% [markdown]
# ### Evaluación del modelo entrenado <font color='blue'>(4.0 ptos)</font>
#
# Debe elegir una métrica y evaluar el modelo en el conjunto de entrenamiento y prueba.
#
# **La elección de su métrica debe estar justificada en base a la distribución de las etiquetas o no se considerará el puntaje**.
#
# **No es válido elegir la métrica "accuracy"**.

# %%
# Escriba su código aquí
## Puede agregar todas las celdas que desee
